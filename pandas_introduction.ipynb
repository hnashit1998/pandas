# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Nashit\\Desktop\\Data Science\\dataset\\COVID-19-Preprint-Data_ver3.csv")

# %%
df
# Out:
#                               DOI Date of Upload  \
# 0     10.1101/2020.05.21.20109017     2020-05-25
# 1     10.1101/2020.05.22.20109231     2020-05-25
# 2     10.1101/2020.05.22.20110163     2020-05-25
# 3     10.1101/2020.05.21.20108738     2020-05-25
# 4     10.1101/2020.05.22.20110155     2020-05-25
# 5     10.1101/2020.05.22.20110254     2020-05-25
# 6     10.1101/2020.05.20.20108167     2020-05-25
# 7     10.1101/2020.05.21.20108233     2020-05-25
# 8     10.1101/2020.05.21.20108910     2020-05-25
# 9     10.1101/2020.05.23.20109496     2020-05-25
# 10    10.1101/2020.05.22.20109579     2020-05-25
# 11    10.1101/2020.05.21.20109207     2020-05-25
# 12    10.1101/2020.05.21.20108993     2020-05-25
# 13    10.1101/2020.05.21.20109041     2020-05-25
# 14    10.1101/2020.05.21.20108894     2020-05-25
# 15    10.1101/2020.05.22.20109991     2020-05-25
# 16    10.1101/2020.05.22.20108845     2020-05-25
# 17    10.1101/2020.05.22.20109850     2020-05-25
# ...

# %%
df['DOI'].max()
# Out:
# '10.1101/782409'

# %%
df['DOI'][df['Abstract']=='COVID-19 point prevalence PCR community testin*']
# Out:
# Series([], Name: DOI, dtype: object)

# %%
df.fillna(0, inplace=True)
